# %%
import pandas as pd
import numpy as np
import json
import copy

from collections import Counter

import os
import glob

import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams['figure.dpi'] = 300
sns.set_theme()

harDir = 'Data/HarassmentAbuse/'
theftDir = 'Data/TheftLostItem/'
chat_file = 'data/subset_1/chat_subset_1.csv'

# %%
# all annotations
domains = ['HarassmentAbuse', 'TheftLostItem']
names = {}
dirs = {}

dirs['HarassmentAbuse'] = glob.glob('../outputs/subset_1/HarassmentAbuse/*.txt', recursive=True)
names['HarassmentAbuse'] = [os.path.basename(x) for x in dirs['HarassmentAbuse']]
dirs['TheftLostItem'] = glob.glob('../outputs/subset_1/TheftLostItem/*.txt', recursive=True)
names['TheftLostItem'] = [os.path.basename(x) for x in dirs['TheftLostItem']]

names
# Out:
# {'HarassmentAbuse': ['event_1001270.txt',
#   'event_1002693.txt',
#   'event_1003647.txt',
#   'event_1008692.txt',
#   'event_1013366.txt',
#   'event_1015396.txt',
#   'event_1015546.txt',
#   'event_1024673.txt',
#   'event_1025925.txt',
#   'event_1038585.txt',
#   'event_1039664.txt',
#   'event_1049621.txt',
#   'event_1059563.txt',
#   'event_1068238.txt',
#   'event_1070064.txt',
#   'event_1088398.txt',
#   'event_1094546.txt',
#   'event_1106380.txt',
#   'event_1124079.txt',
#   'event_1132921.txt',
#   'event_1142902.txt',
#   'event_1162046.txt',
#   'event_1162552.txt',
#   'event_1168808.txt',
#   'event_1204540.txt',
#   'event_1211586.txt',
#   'event_1214862.txt',
#   'event_1221081.txt',
#   'event_1224372.txt',
#   'event_1227902.txt',
#   'event_1230056.txt',
#   'event_1231902.txt',
#   'event_1234843.txt',
#   'event_1239324.txt',
#   'event_1240344.txt',
#   'event_1252184.txt',
#   'event_1252749.txt',
#   'event_1253319.txt',
#   'event_1254679.txt',
#   'event_1254988.txt',
#   'event_1255054.txt',
#   'event_1255114.txt',
#   'event_1255772.txt',
#   'event_1257202.txt',
#   'event_1258269.txt',
#   'event_1260704.txt',
#   'event_1263036.txt',
#   'event_1266166.txt',
#   'event_1269557.txt',
#   'event_1276329.txt',
#   'event_1277264.txt',
#   'event_1279615.txt',
#   'event_1280980.txt',
#   'event_1281662.txt',
#   'event_1284370.txt',
#   'event_1285180.txt',
#   'event_1285421.txt',
#   'event_1285541.txt',
#   'event_1285725.txt',
#   'event_1291401.txt',
#   'event_1294355.txt',
#   'event_1294770.txt',
#   'event_1301329.txt',
#   'event_1302619.txt',
#   'event_1312002.txt',
#   'event_1315120.txt',
#   'event_1315541.txt',
#   'event_1318394.txt',
#   'event_1318660.txt',
#   'event_1321686.txt',
#   'event_1322947.txt',
#   'event_1327136.txt',
#   'event_1330062.txt',
#   'event_1330417.txt',
#   'event_1330793.txt',
#   'event_1332048.txt',
#   'event_1333802.txt',
#   'event_1340120.txt',
#   'event_1341237.txt',
#   'event_1343548.txt',
#   'event_1344060.txt',
#   'event_1344062.txt',
#   'event_1351719.txt',
#   'event_1353675.txt',
#   'event_1361070.txt',
#   'event_1361103.txt',
#   'event_1362677.txt',
#   'event_1363127.txt',
#   'event_1364205.txt',
#   'event_1364406.txt',
#   'event_1364680.txt',
#   'event_1365216.txt',
#   'event_1365340.txt',
#   'event_1368013.txt',
#   'event_1371084.txt',
#   'event_1371355.txt',
#   'event_1375231.txt',
#   'event_1376172.txt',
#   'event_1377895.txt',
#   'event_1384440.txt',
#   'event_1384507.txt',
#   'event_1390263.txt',
#   'event_1392754.txt',
#   'event_1399528.txt',
#   'event_1401914.txt',
#   'event_1403331.txt',
#   'event_1403557.txt',
#   'event_1405271.txt',
#   'event_1405632.txt',
#   'event_1406227.txt',
#   'event_1409858.txt',
#   'event_1414129.txt',
#   'event_1415420.txt',
#   'event_1419414.txt',
#   'event_1421008.txt',
#   'event_1430220.txt',
#   'event_1431656.txt',
#   'event_1441473.txt',
#   'event_1443436.txt',
#   'event_1443489.txt',
#   'event_1444237.txt',
#   'event_1448835.txt',
#   'event_1449026.txt',
#   'event_1449050.txt',
#   'event_1451555.txt',
#   'event_1451869.txt',
#   'event_1453460.txt',
#   'event_1461867.txt',
#   'event_1462929.txt',
#   'event_1478456.txt',
#   'event_1483733.txt',
#   'event_1497528.txt',
#   'event_1503071.txt',
#   'event_1511903.txt',
#   'event_1521696.txt',
#   'event_1522737.txt',
#   'event_1523664.txt',
#   'event_1530901.txt',
#   'event_1534500.txt',
#   'event_1545040.txt',
#   'event_1547394.txt',
#   'event_1550055.txt',
#   'event_1550094.txt',
#   'event_1561670.txt',
#   'event_1573471.txt',
#   'event_1574096.txt',
#   'event_1574240.txt',
#   'event_1575126.txt',
#   'event_1577323.txt',
#   'event_1579861.txt',
#   'event_1582507.txt',
#   'event_1582544.txt',
#   'event_1591474.txt',
#   'event_1592307.txt',
#   'event_1593319.txt',
#   'event_1594029.txt',
#   'event_1595975.txt',
#   'event_1596199.txt',
#   'event_1597908.txt',
#   'event_1604636.txt',
#   'event_1605677.txt',
#   'event_1605680.txt',
#   'event_1606091.txt',
#   'event_1608422.txt',
#   'event_1610769.txt',
#   'event_1610789.txt',
#   'event_1611127.txt',
#   'event_1612481.txt',
#   'event_1612860.txt',
#   'event_1614318.txt',
#   'event_1622028.txt',
#   'event_1622529.txt',
#   'event_1623561.txt',
#   'event_1630792.txt',
#   'event_1632786.txt',
#   'event_1635995.txt',
#   'event_1636448.txt',
#   'event_1652341.txt',
#   'event_1654178.txt',
#   'event_1659342.txt',
#   'event_1660363.txt',
#   'event_1660382.txt',
#   'event_1664150.txt',
#   'event_1665466.txt',
#   'event_1667333.txt',
#   'event_1667740.txt',
#   'event_1667795.txt',
#   'event_1668501.txt',
#   'event_1670450.txt',
#   'event_1672475.txt',
#   'event_1674191.txt',
#   'event_1675715.txt',
#   'event_1677520.txt',
#   'event_1681179.txt',
#   'event_1684640.txt',
#   'event_1686190.txt',
#   'event_1688085.txt',
#   'event_1689526.txt',
#   'event_1691328.txt',
#   'event_1697364.txt',
#   'event_1697522.txt',
#   'event_1699496.txt',
#   'event_1701446.txt',
#   'event_1701455.txt',
#   'event_1702502.txt',
#   'event_1704157.txt',
#   'event_1706504.txt',
#   'event_1706995.txt',
#   'event_1707056.txt',
#   'event_1710559.txt',
#   'event_1711420.txt',
#   'event_1712706.txt',
#   'event_1712766.txt',
#   'event_1720374.txt',
#   'event_1720421.txt',
#   'event_1721186.txt',
#   'event_1721305.txt',
#   'event_1722254.txt',
#   'event_1724101.txt',
#   'event_1724502.txt',
#   'event_1727206.txt',
#   'event_1731303.txt',
#   'event_1734914.txt',
#   'event_1737666.txt',
#   'event_1739299.txt',
#   'event_1741668.txt',
#   'event_1743181.txt',
#   'event_1746266.txt',
#   'event_1747301.txt',
#   'event_1752273.txt',
#   'event_1753140.txt',
#   'event_1754863.txt',
#   'event_1792568.txt',
#   'event_1794137.txt',
#   'event_1794891.txt',
#   'event_1810119.txt',
#   'event_1820467.txt',
#   'event_1832888.txt',
#   'event_1843972.txt',
#   'event_1847474.txt',
#   'event_1850316.txt',
#   'event_782641.txt',
#   'event_796213.txt',
#   'event_796431.txt',
#   'event_804515.txt',
#   'event_805381.txt',
#   'event_807927.txt',
#   'event_808000.txt',
#   'event_812173.txt',
#   'event_820606.txt',
#   'event_821632.txt',
#   'event_824284.txt',
#   'event_826282.txt',
#   'event_830009.txt',
#   'event_833178.txt',
#   'event_834673.txt',
#   'event_847112.txt',
#   'event_854906.txt',
#   'event_858033.txt',
#   'event_861686.txt',
#   'event_864394.txt',
#   'event_870233.txt',
#   'event_871205.txt',
#   'event_873969.txt',
#   'event_876348.txt',
#   'event_876897.txt',
#   'event_877867.txt',
#   'event_880004.txt',
#   'event_880524.txt',
#   'event_885522.txt',
#   'event_888539.txt',
#   'event_890158.txt',
#   'event_897932.txt',
#   'event_903166.txt',
#   'event_916241.txt',
#   'event_924585.txt',
#   'event_930677.txt',
#   'event_935101.txt',
#   'event_939944.txt',
#   'event_946230.txt',
#   'event_947630.txt',
#   'event_947799.txt',
#   'event_949530.txt',
#   'event_950518.txt',
#   'event_951605.txt',
#   'event_953710.txt',
#   'event_956162.txt',
#   'event_958051.txt',
#   'event_962296.txt',
#   'event_967854.txt',
#   'event_971564.txt',
#   'event_973684.txt',
#   'event_975066.txt',
#   'event_985115.txt',
#   'event_987214.txt',
#   'event_992206.txt',
#   'event_992271.txt',
#   'event_996979.txt',
#   'event_999891.txt'],
#  'TheftLostItem': ['event_1001959.txt',
#   'event_1008352.txt',
#   'event_1015289.txt',
#   'event_1019114.txt',
#   'event_1025624.txt',
#   'event_1025922.txt',
#   'event_1026014.txt',
#   'event_1026630.txt',
#   'event_1029219.txt',
#   'event_1029258.txt',
#   'event_1029969.txt',
#   'event_1032487.txt',
#   'event_1041115.txt',
#   'event_1044414.txt',
#   'event_1051534.txt',
#   'event_1054051.txt',
#   'event_1054347.txt',
#   'event_1085132.txt',
#   'event_1118594.txt',
#   'event_1119003.txt',
#   'event_1119278.txt',
#   'event_1123605.txt',
#   'event_1124841.txt',
#   'event_1143435.txt',
#   'event_1145210.txt',
#   'event_1163038.txt',
#   'event_1190017.txt',
#   'event_1200252.txt',
#   'event_1206297.txt',
#   'event_1212420.txt',
#   'event_1216129.txt',
#   'event_1216322.txt',
#   'event_1218058.txt',
#   'event_1219692.txt',
#   'event_1222351.txt',
#   'event_1227840.txt',
#   'event_1229574.txt',
#   'event_1234423.txt',
#   'event_1234509.txt',
#   'event_1236506.txt',
#   'event_1237251.txt',
#   'event_1240903.txt',
#   'event_1242980.txt',
#   'event_1250496.txt',
#   'event_1250997.txt',
#   'event_1251167.txt',
#   'event_1256873.txt',
#   'event_1258165.txt',
#   'event_1262129.txt',
#   'event_1263148.txt',
#   'event_1267275.txt',
#   'event_1268730.txt',
#   'event_1268808.txt',
#   'event_1269282.txt',
#   'event_1272069.txt',
#   'event_1272171.txt',
#   'event_1272277.txt',
#   'event_1275749.txt',
#   'event_1280899.txt',
#   'event_1281192.txt',
#   'event_1282908.txt',
#   'event_1285447.txt',
#   'event_1289508.txt',
#   'event_1291751.txt',
#   'event_1293935.txt',
#   'event_1296519.txt',
#   'event_1297605.txt',
#   'event_1297710.txt',
#   'event_1300485.txt',
#   'event_1302494.txt',
#   'event_1302499.txt',
#   'event_1309893.txt',
#   'event_1311212.txt',
#   'event_1311978.txt',
#   'event_1313433.txt',
#   'event_1314038.txt',
#   'event_1314096.txt',
#   'event_1317283.txt',
#   'event_1320229.txt',
#   'event_1320328.txt',
#   'event_1322053.txt',
#   'event_1322302.txt',
#   'event_1328093.txt',
#   'event_1328178.txt',
#   'event_1333463.txt',
#   'event_1334103.txt',
#   'event_1336248.txt',
#   'event_1337270.txt',
#   'event_1337625.txt',
#   'event_1339463.txt',
#   'event_1344214.txt',
#   'event_1349076.txt',
#   'event_1350632.txt',
#   'event_1351619.txt',
#   'event_1353067.txt',
#   'event_1355916.txt',
#   'event_1360833.txt',
#   'event_1361929.txt',
#   'event_1362941.txt',
#   'event_1366919.txt',
#   'event_1380000.txt',
#   'event_1388279.txt',
#   'event_1392836.txt',
#   'event_1393077.txt',
#   'event_1394107.txt',
#   'event_1394276.txt',
#   'event_1403395.txt',
#   'event_1407769.txt',
#   'event_1409929.txt',
#   'event_1410424.txt',
#   'event_1412278.txt',
#   'event_1417649.txt',
#   'event_1424569.txt',
#   'event_1428504.txt',
#   'event_1430279.txt',
#   'event_1438882.txt',
#   'event_1442081.txt',
#   'event_1444516.txt',
#   'event_1445444.txt',
#   'event_1447006.txt',
#   'event_1447201.txt',
#   'event_1448070.txt',
#   'event_1449511.txt',
#   'event_1459119.txt',
#   'event_1460339.txt',
#   'event_1474001.txt',
#   'event_1475083.txt',
#   'event_1503341.txt',
#   'event_1511865.txt',
#   'event_1512193.txt',
#   'event_1523929.txt',
#   'event_1528639.txt',
#   'event_1530125.txt',
#   'event_1532939.txt',
#   'event_1537261.txt',
#   'event_1538396.txt',
#   'event_1543078.txt',
#   'event_1545637.txt',
#   'event_1546091.txt',
#   'event_1550825.txt',
#   'event_1554606.txt',
#   'event_1559270.txt',
#   'event_1565579.txt',
#   'event_1566812.txt',
#   'event_1578995.txt',
#   'event_1579288.txt',
#   'event_1581488.txt',
#   'event_1582370.txt',
#   'event_1582407.txt',
#   'event_1582437.txt',
#   'event_1585595.txt',
#   'event_1586129.txt',
#   'event_1587983.txt',
#   'event_1593220.txt',
#   'event_1593270.txt',
#   'event_1595281.txt',
#   'event_1603554.txt',
#   'event_1607658.txt',
#   'event_1610697.txt',
#   'event_1611384.txt',
#   'event_1614716.txt',
#   'event_1615019.txt',
#   'event_1618471.txt',
#   'event_1623282.txt',
#   'event_1623638.txt',
#   'event_1632001.txt',
#   'event_1635475.txt',
#   'event_1637574.txt',
#   'event_1644701.txt',
#   'event_1646061.txt',
#   'event_1652051.txt',
#   'event_1652290.txt',
#   'event_1655692.txt',
#   'event_1658451.txt',
#   'event_1660387.txt',
#   'event_1663594.txt',
#   'event_1664789.txt',
#   'event_1667457.txt',
#   'event_1670447.txt',
#   'event_1680515.txt',
#   'event_1688581.txt',
#   'event_1692778.txt',
#   'event_1694324.txt',
#   'event_1696331.txt',
#   'event_1696771.txt',
#   'event_1698679.txt',
#   'event_1698765.txt',
#   'event_1700452.txt',
#   'event_1700668.txt',
#   'event_1700722.txt',
#   'event_1706562.txt',
#   'event_1707117.txt',
#   'event_1707355.txt',
#   'event_1709662.txt',
#   'event_1714666.txt',
#   'event_1722658.txt',
#   'event_1722800.txt',
#   'event_1722881.txt',
#   'event_1722954.txt',
#   'event_1728379.txt',
#   'event_1729518.txt',
#   'event_1733325.txt',
#   'event_1738631.txt',
#   'event_1743009.txt',
#   'event_1747697.txt',
#   'event_1749478.txt',
#   'event_1749844.txt',
#   'event_1764281.txt',
#   'event_1764862.txt',
#   'event_1765702.txt',
#   'event_1774975.txt',
#   'event_1780903.txt',
#   'event_1782100.txt',
#   'event_1785939.txt',
#   'event_1804385.txt',
#   'event_1811303.txt',
#   'event_1818808.txt',
#   'event_1869637.txt',
#   'event_1882181.txt',
#   'event_785248.txt',
#   'event_785339.txt',
#   'event_797838.txt',
#   'event_803374.txt',
#   'event_813742.txt',
#   'event_815871.txt',
#   'event_818078.txt',
#   'event_821662.txt',
#   'event_822155.txt',
#   'event_824217.txt',
#   'event_827199.txt',
#   'event_834376.txt',
#   'event_834837.txt',
#   'event_838732.txt',
#   'event_840142.txt',
#   'event_840760.txt',
#   'event_849218.txt',
#   'event_850582.txt',
#   'event_852642.txt',
#   'event_854506.txt',
#   'event_854986.txt',
#   'event_862647.txt',
#   'event_863662.txt',
#   'event_866615.txt',
#   'event_867539.txt',
#   'event_872396.txt',
#   'event_874622.txt',
#   'event_875566.txt',
#   'event_878298.txt',
#   'event_882142.txt',
#   'event_883968.txt',
#   'event_888199.txt',
#   'event_892665.txt',
#   'event_894405.txt',
#   'event_895832.txt',
#   'event_896110.txt',
#   'event_898318.txt',
#   'event_903359.txt',
#   'event_904103.txt',
#   'event_904605.txt',
#   'event_916039.txt',
#   'event_917999.txt',
#   'event_923896.txt',
#   'event_928735.txt',
#   'event_932026.txt',
#   'event_932318.txt',
#   'event_943482.txt',
#   'event_956788.txt',
#   'event_957136.txt',
#   'event_963824.txt',
#   'event_966351.txt',
#   'event_968234.txt',
#   'event_974040.txt',
#   'event_974943.txt',
#   'event_978021.txt',
#   'event_980201.txt',
#   'event_987038.txt',
#   'event_989017.txt',
#   'event_991263.txt',
#   'event_991754.txt',
#   'event_993897.txt']}

# %%
{k:len(names[k]) for k in names}
# Out:
# {'HarassmentAbuse': 299, 'TheftLostItem': 280}

# %%
class Conversation():
    def __init__(self):
        self.texts = {} # {utter#: text}
        self.args_by_turn = {} # {utter#: {arg: [text]}}
        self.args_accum_by_turn = {} # accumulated args by turn {utter#: {arg: set(text)}} 
        self.args_all = {} # {arg: set(text)}
        self.event_id = None
        self.domain = None
    
    def from_file(self, file_path):
        self.event_id = file_path.split('_')[-1].split('.')[0]
        for domain in domains:
            if domain in file_path:
                self.domain = domain
        args_accum = {}
        self.args_by_turn = {}
        self.args_accum_by_turn = {}
        with open(file_path, 'r') as f:
            for i, line in enumerate(f):
                args = eval(line)
                for k in args:
                    if k not in args_accum:
                        args_accum[k] = set()
                    args_accum[k].update(args[k])
                self.args_by_turn[i] = {k: set(args[k]) for k in args}
                self.args_accum_by_turn[i] = copy.deepcopy(args_accum)
            self.args_all = copy.deepcopy(args_accum)
        # print(self.args_all)
        return self

    def to_dict(self, by_turn=False):
        if by_turn:
            dicts = []
            for tid in self.args_by_turn:
                dicts.append({
                'event_id': self.event_id,
                'domain': self.domain,
                'turn_id': tid,
                'args_all': self.args_all,
                'args_by_turn': self.args_by_turn[tid],
                'args_accum_by_turn': self.args_accum_by_turn[tid],
            })
            return dicts
        else:
            return {
                'event_id': self.event_id,
                'domain': self.domain,
                'args_all': self.args_all,
                'args_by_turn': self.args_by_turn,
                'args_accum_by_turn': self.args_accum_by_turn,
            }

# %%
file_path = '../outputs/subset_1/HarassmentAbuse/event_782641.txt'

args_accum = {}
args_by_turn = {}
args_accum_by_turn = {}
with open(file_path, 'r') as f:
    for i, line in enumerate(f):
        args = eval(line)
        for k in args:
            if k not in args_accum:
                args_accum[k] = set()
            args_accum[k].update(args[k])
        args_by_turn[i] = {k: set(args[k]) for k in args}
        args_accum_by_turn[i] = copy.deepcopy(args_accum)
    args_all = copy.deepcopy(args_accum)

# %%
args_by_turn
# Out:
# {0: {'Target-ARG': set(),
#   'Place-Arg': set(),
#   'Attacker-Arg': set(),
#   'End_Time-Arg': set()},
#  1: {'Target-ARG': set(),
#   'Place-Arg': set(),
#   'Attacker-Arg': set(),
#   'End_Time-Arg': set()},
#  2: {'Target-ARG': set(),
#   'Place-Arg': {' bus stop/admissions area'},
#   'Attacker-Arg': set(),
#   'End_Time-Arg': set()},
#  3: {'Target-ARG': {''},
#   'Place-Arg': {' bus stop/admissions area'},
#   'Attacker-Arg': set(),
#   'End_Time-Arg': set()},
#  4: {'Target-ARG': {'Homeless man'},
#   'Place-Arg': {' bus stop/admissions area'},
#   'Attacker-Arg': set(),
#   'End_Time-Arg': set()}}

# %% [markdown]
# ### Analysis

# %%
convos = []
for domain in domains:
    for dir in dirs[domain]:
        convo = Conversation().from_file(dir)
        convos.extend(convo.to_dict(by_turn=True))

# %%
convos
# Out:
# [{'event_id': '1001270',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 0,
#   'args_all': {'Target-ARG': set(),
#    'Place-Arg': {'ORG] Locker Room Showers'},
#    'Attacker-Arg': {' [NORP] male'},
#    'End_Time-Arg': {''}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {'ORG] Locker Room Showers'},
#    'Attacker-Arg': {' [NORP] male'},
#    'End_Time-Arg': {''}},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {'ORG] Locker Room Showers'},
#    'Attacker-Arg': {' [NORP] male'},
#    'End_Time-Arg': {''}}},
#  {'event_id': '1001270',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 1,
#   'args_all': {'Target-ARG': set(),
#    'Place-Arg': {'ORG] Locker Room Showers'},
#    'Attacker-Arg': {' [NORP] male'},
#    'End_Time-Arg': {''}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {'ORG] Locker Room Showers'},
#    'Attacker-Arg': {' [NORP] male'},
#    'End_Time-Arg': set()},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {'ORG] Locker Room Showers'},
#    'Attacker-Arg': {' [NORP] male'},
#    'End_Time-Arg': {''}}},
#  {'event_id': '1001270',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 2,
#   'args_all': {'Target-ARG': set(),
#    'Place-Arg': {'ORG] Locker Room Showers'},
#    'Attacker-Arg': {' [NORP] male'},
#    'End_Time-Arg': {''}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {'ORG] Locker Room Showers'},
#    'Attacker-Arg': {' [NORP] male'},
#    'End_Time-Arg': set()},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {'ORG] Locker Room Showers'},
#    'Attacker-Arg': {' [NORP] male'},
#    'End_Time-Arg': {''}}},
#  {'event_id': '1001270',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 3,
#   'args_all': {'Target-ARG': set(),
#    'Place-Arg': {'ORG] Locker Room Showers'},
#    'Attacker-Arg': {' [NORP] male'},
#    'End_Time-Arg': {''}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {'ORG] Locker Room Showers'},
#    'Attacker-Arg': {' [NORP] male'},
#    'End_Time-Arg': set()},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {'ORG] Locker Room Showers'},
#    'Attacker-Arg': {' [NORP] male'},
#    'End_Time-Arg': {''}}},
#  {'event_id': '1001270',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 4,
#   'args_all': {'Target-ARG': set(),
#    'Place-Arg': {'ORG] Locker Room Showers'},
#    'Attacker-Arg': {' [NORP] male'},
#    'End_Time-Arg': {''}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {'ORG] Locker Room Showers'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': set()},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {'ORG] Locker Room Showers'},
#    'Attacker-Arg': {' [NORP] male'},
#    'End_Time-Arg': {''}}},
#  {'event_id': '1001270',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 5,
#   'args_all': {'Target-ARG': set(),
#    'Place-Arg': {'ORG] Locker Room Showers'},
#    'Attacker-Arg': {' [NORP] male'},
#    'End_Time-Arg': {''}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {'ORG] Locker Room Showers'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': set()},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {'ORG] Locker Room Showers'},
#    'Attacker-Arg': {' [NORP] male'},
#    'End_Time-Arg': {''}}},
#  {'event_id': '1001270',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 6,
#   'args_all': {'Target-ARG': set(),
#    'Place-Arg': {'ORG] Locker Room Showers'},
#    'Attacker-Arg': {' [NORP] male'},
#    'End_Time-Arg': {''}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {'ORG] Locker Room Showers'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': set()},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {'ORG] Locker Room Showers'},
#    'Attacker-Arg': {' [NORP] male'},
#    'End_Time-Arg': {''}}},
#  {'event_id': '1001270',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 7,
#   'args_all': {'Target-ARG': set(),
#    'Place-Arg': {'ORG] Locker Room Showers'},
#    'Attacker-Arg': {' [NORP] male'},
#    'End_Time-Arg': {''}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {'ORG] Locker Room Showers'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': set()},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {'ORG] Locker Room Showers'},
#    'Attacker-Arg': {' [NORP] male'},
#    'End_Time-Arg': {''}}},
#  {'event_id': '1001270',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 8,
#   'args_all': {'Target-ARG': set(),
#    'Place-Arg': {'ORG] Locker Room Showers'},
#    'Attacker-Arg': {' [NORP] male'},
#    'End_Time-Arg': {''}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {'ORG] Locker Room Showers'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': set()},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {'ORG] Locker Room Showers'},
#    'Attacker-Arg': {' [NORP] male'},
#    'End_Time-Arg': {''}}},
#  {'event_id': '1001270',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 9,
#   'args_all': {'Target-ARG': set(),
#    'Place-Arg': {'ORG] Locker Room Showers'},
#    'Attacker-Arg': {' [NORP] male'},
#    'End_Time-Arg': {''}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {'ORG] Locker Room Showers'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': set()},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {'ORG] Locker Room Showers'},
#    'Attacker-Arg': {' [NORP] male'},
#    'End_Time-Arg': {''}}},
#  {'event_id': '1001270',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 10,
#   'args_all': {'Target-ARG': set(),
#    'Place-Arg': {'ORG] Locker Room Showers'},
#    'Attacker-Arg': {' [NORP] male'},
#    'End_Time-Arg': {''}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {'ORG] Locker Room Showers'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': set()},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {'ORG] Locker Room Showers'},
#    'Attacker-Arg': {' [NORP] male'},
#    'End_Time-Arg': {''}}},
#  {'event_id': '1002693',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 0,
#   'args_all': {'Target-ARG': set(),
#    'Place-Arg': set(),
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {"Since attending Dr. [PERSON]'s [ACRONYM] ### class"}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': set(),
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {"Since attending Dr. [PERSON]'s [ACRONYM] ### class"}},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': set(),
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {"Since attending Dr. [PERSON]'s [ACRONYM] ### class"}}},
#  {'event_id': '1002693',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 1,
#   'args_all': {'Target-ARG': set(),
#    'Place-Arg': set(),
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {"Since attending Dr. [PERSON]'s [ACRONYM] ### class"}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': set(),
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {"Since attending Dr. [PERSON]'s [ACRONYM] ### class"}},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': set(),
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {"Since attending Dr. [PERSON]'s [ACRONYM] ### class"}}},
#  {'event_id': '1002693',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 2,
#   'args_all': {'Target-ARG': set(),
#    'Place-Arg': set(),
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {"Since attending Dr. [PERSON]'s [ACRONYM] ### class"}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': set(),
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {"Since attending Dr. [PERSON]'s [ACRONYM] ### class"}},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': set(),
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {"Since attending Dr. [PERSON]'s [ACRONYM] ### class"}}},
#  {'event_id': '1002693',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 3,
#   'args_all': {'Target-ARG': set(),
#    'Place-Arg': set(),
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {"Since attending Dr. [PERSON]'s [ACRONYM] ### class"}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': set(),
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {"Since attending Dr. [PERSON]'s [ACRONYM] ### class"}},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': set(),
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {"Since attending Dr. [PERSON]'s [ACRONYM] ### class"}}},
#  {'event_id': '1002693',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 4,
#   'args_all': {'Target-ARG': set(),
#    'Place-Arg': set(),
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {"Since attending Dr. [PERSON]'s [ACRONYM] ### class"}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': set(),
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {"Since attending Dr. [PERSON]'s [ACRONYM] ### class"}},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': set(),
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {"Since attending Dr. [PERSON]'s [ACRONYM] ### class"}}},
#  {'event_id': '1003647',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 0,
#   'args_all': {'Target-ARG': set(),
#    'Place-Arg': {' [LOC] parking lot behind the rec center'},
#    'Attacker-Arg': {' a older gentleman'},
#    'End_Time-Arg': {' around #pm'}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' [LOC] parking lot behind the rec center'},
#    'Attacker-Arg': {' a older gentleman'},
#    'End_Time-Arg': {' around #pm'}},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' [LOC] parking lot behind the rec center'},
#    'Attacker-Arg': {' a older gentleman'},
#    'End_Time-Arg': {' around #pm'}}},
#  {'event_id': '1003647',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 1,
#   'args_all': {'Target-ARG': set(),
#    'Place-Arg': {' [LOC] parking lot behind the rec center'},
#    'Attacker-Arg': {' a older gentleman'},
#    'End_Time-Arg': {' around #pm'}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' [LOC] parking lot behind the rec center'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': set()},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' [LOC] parking lot behind the rec center'},
#    'Attacker-Arg': {' a older gentleman'},
#    'End_Time-Arg': {' around #pm'}}},
#  {'event_id': '1003647',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 2,
#   'args_all': {'Target-ARG': set(),
#    'Place-Arg': {' [LOC] parking lot behind the rec center'},
#    'Attacker-Arg': {' a older gentleman'},
#    'End_Time-Arg': {' around #pm'}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' [LOC] parking lot behind the rec center'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': set()},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' [LOC] parking lot behind the rec center'},
#    'Attacker-Arg': {' a older gentleman'},
#    'End_Time-Arg': {' around #pm'}}},
#  {'event_id': '1003647',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 3,
#   'args_all': {'Target-ARG': set(),
#    'Place-Arg': {' [LOC] parking lot behind the rec center'},
#    'Attacker-Arg': {' a older gentleman'},
#    'End_Time-Arg': {' around #pm'}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' [LOC] parking lot behind the rec center'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {' around #pm'}},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' [LOC] parking lot behind the rec center'},
#    'Attacker-Arg': {' a older gentleman'},
#    'End_Time-Arg': {' around #pm'}}},
#  {'event_id': '1003647',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 4,
#   'args_all': {'Target-ARG': set(),
#    'Place-Arg': {' [LOC] parking lot behind the rec center'},
#    'Attacker-Arg': {' a older gentleman'},
#    'End_Time-Arg': {' around #pm'}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' [LOC] parking lot behind the rec center'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {' around #pm'}},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' [LOC] parking lot behind the rec center'},
#    'Attacker-Arg': {' a older gentleman'},
#    'End_Time-Arg': {' around #pm'}}},
#  {'event_id': '1003647',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 5,
#   'args_all': {'Target-ARG': set(),
#    'Place-Arg': {' [LOC] parking lot behind the rec center'},
#    'Attacker-Arg': {' a older gentleman'},
#    'End_Time-Arg': {' around #pm'}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' [LOC] parking lot behind the rec center'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {' around #pm'}},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' [LOC] parking lot behind the rec center'},
#    'Attacker-Arg': {' a older gentleman'},
#    'End_Time-Arg': {' around #pm'}}},
#  {'event_id': '1003647',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 6,
#   'args_all': {'Target-ARG': set(),
#    'Place-Arg': {' [LOC] parking lot behind the rec center'},
#    'Attacker-Arg': {' a older gentleman'},
#    'End_Time-Arg': {' around #pm'}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' [LOC] parking lot behind the rec center'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {' around #pm'}},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' [LOC] parking lot behind the rec center'},
#    'Attacker-Arg': {' a older gentleman'},
#    'End_Time-Arg': {' around #pm'}}},
#  {'event_id': '1003647',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 7,
#   'args_all': {'Target-ARG': set(),
#    'Place-Arg': {' [LOC] parking lot behind the rec center'},
#    'Attacker-Arg': {' a older gentleman'},
#    'End_Time-Arg': {' around #pm'}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' [LOC] parking lot behind the rec center'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {' around #pm'}},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' [LOC] parking lot behind the rec center'},
#    'Attacker-Arg': {' a older gentleman'},
#    'End_Time-Arg': {' around #pm'}}},
#  {'event_id': '1003647',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 8,
#   'args_all': {'Target-ARG': set(),
#    'Place-Arg': {' [LOC] parking lot behind the rec center'},
#    'Attacker-Arg': {' a older gentleman'},
#    'End_Time-Arg': {' around #pm'}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' [LOC] parking lot behind the rec center'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {' around #pm'}},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' [LOC] parking lot behind the rec center'},
#    'Attacker-Arg': {' a older gentleman'},
#    'End_Time-Arg': {' around #pm'}}},
#  {'event_id': '1003647',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 9,
#   'args_all': {'Target-ARG': set(),
#    'Place-Arg': {' [LOC] parking lot behind the rec center'},
#    'Attacker-Arg': {' a older gentleman'},
#    'End_Time-Arg': {' around #pm'}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' [LOC] parking lot behind the rec center'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {' around #pm'}},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' [LOC] parking lot behind the rec center'},
#    'Attacker-Arg': {' a older gentleman'},
#    'End_Time-Arg': {' around #pm'}}},
#  {'event_id': '1003647',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 10,
#   'args_all': {'Target-ARG': set(),
#    'Place-Arg': {' [LOC] parking lot behind the rec center'},
#    'Attacker-Arg': {' a older gentleman'},
#    'End_Time-Arg': {' around #pm'}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' [LOC] parking lot behind the rec center'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {' around #pm'}},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' [LOC] parking lot behind the rec center'},
#    'Attacker-Arg': {' a older gentleman'},
#    'End_Time-Arg': {' around #pm'}}},
#  {'event_id': '1008692',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 0,
#   'args_all': {'Target-ARG': set(),
#    'Place-Arg': {' in front of canteen'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': set()},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': set(),
#    'Attacker-Arg': set(),
#    'End_Time-Arg': set()},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': set(),
#    'Attacker-Arg': set(),
#    'End_Time-Arg': set()}},
#  {'event_id': '1008692',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 1,
#   'args_all': {'Target-ARG': set(),
#    'Place-Arg': {' in front of canteen'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': set()},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': set(),
#    'Attacker-Arg': set(),
#    'End_Time-Arg': set()},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': set(),
#    'Attacker-Arg': set(),
#    'End_Time-Arg': set()}},
#  {'event_id': '1008692',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 2,
#   'args_all': {'Target-ARG': set(),
#    'Place-Arg': {' in front of canteen'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': set()},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': set(),
#    'Attacker-Arg': set(),
#    'End_Time-Arg': set()},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': set(),
#    'Attacker-Arg': set(),
#    'End_Time-Arg': set()}},
#  {'event_id': '1008692',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 3,
#   'args_all': {'Target-ARG': set(),
#    'Place-Arg': {' in front of canteen'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': set()},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' in front of canteen'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': set()},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' in front of canteen'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': set()}},
#  {'event_id': '1008692',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 4,
#   'args_all': {'Target-ARG': set(),
#    'Place-Arg': {' in front of canteen'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': set()},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' in front of canteen'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': set()},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' in front of canteen'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': set()}},
#  {'event_id': '1008692',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 5,
#   'args_all': {'Target-ARG': set(),
#    'Place-Arg': {' in front of canteen'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': set()},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' in front of canteen'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': set()},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' in front of canteen'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': set()}},
#  {'event_id': '1013366',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 0,
#   'args_all': {'Target-ARG': set(),
#    'Place-Arg': {'', ' between the [GPE] library and the [ORG]'},
#    'Attacker-Arg': {''},
#    'End_Time-Arg': {'About ##-## minutes ago', 'How long ago'}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' between the [GPE] library and the [ORG]'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': set()},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' between the [GPE] library and the [ORG]'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': set()}},
#  {'event_id': '1013366',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 1,
#   'args_all': {'Target-ARG': set(),
#    'Place-Arg': {'', ' between the [GPE] library and the [ORG]'},
#    'Attacker-Arg': {''},
#    'End_Time-Arg': {'About ##-## minutes ago', 'How long ago'}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' between the [GPE] library and the [ORG]'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': set()},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' between the [GPE] library and the [ORG]'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': set()}},
#  {'event_id': '1013366',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 2,
#   'args_all': {'Target-ARG': set(),
#    'Place-Arg': {'', ' between the [GPE] library and the [ORG]'},
#    'Attacker-Arg': {''},
#    'End_Time-Arg': {'About ##-## minutes ago', 'How long ago'}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' between the [GPE] library and the [ORG]'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {'How long ago'}},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' between the [GPE] library and the [ORG]'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {'How long ago'}}},
#  {'event_id': '1013366',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 3,
#   'args_all': {'Target-ARG': set(),
#    'Place-Arg': {'', ' between the [GPE] library and the [ORG]'},
#    'Attacker-Arg': {''},
#    'End_Time-Arg': {'About ##-## minutes ago', 'How long ago'}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {''},
#    'Attacker-Arg': {''},
#    'End_Time-Arg': {'About ##-## minutes ago'}},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {'', ' between the [GPE] library and the [ORG]'},
#    'Attacker-Arg': {''},
#    'End_Time-Arg': {'About ##-## minutes ago', 'How long ago'}}},
#  {'event_id': '1013366',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 4,
#   'args_all': {'Target-ARG': set(),
#    'Place-Arg': {'', ' between the [GPE] library and the [ORG]'},
#    'Attacker-Arg': {''},
#    'End_Time-Arg': {'About ##-## minutes ago', 'How long ago'}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {''},
#    'Attacker-Arg': {''},
#    'End_Time-Arg': {'About ##-## minutes ago'}},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {'', ' between the [GPE] library and the [ORG]'},
#    'Attacker-Arg': {''},
#    'End_Time-Arg': {'About ##-## minutes ago', 'How long ago'}}},
#  {'event_id': '1013366',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 5,
#   'args_all': {'Target-ARG': set(),
#    'Place-Arg': {'', ' between the [GPE] library and the [ORG]'},
#    'Attacker-Arg': {''},
#    'End_Time-Arg': {'About ##-## minutes ago', 'How long ago'}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' between the [GPE] library and the [ORG]'},
#    'Attacker-Arg': {''},
#    'End_Time-Arg': {'About ##-## minutes ago'}},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {'', ' between the [GPE] library and the [ORG]'},
#    'Attacker-Arg': {''},
#    'End_Time-Arg': {'About ##-## minutes ago', 'How long ago'}}},
#  {'event_id': '1013366',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 6,
#   'args_all': {'Target-ARG': set(),
#    'Place-Arg': {'', ' between the [GPE] library and the [ORG]'},
#    'Attacker-Arg': {''},
#    'End_Time-Arg': {'About ##-## minutes ago', 'How long ago'}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' between the [GPE] library and the [ORG]'},
#    'Attacker-Arg': {''},
#    'End_Time-Arg': {'About ##-## minutes ago'}},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {'', ' between the [GPE] library and the [ORG]'},
#    'Attacker-Arg': {''},
#    'End_Time-Arg': {'About ##-## minutes ago', 'How long ago'}}},
#  {'event_id': '1013366',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 7,
#   'args_all': {'Target-ARG': set(),
#    'Place-Arg': {'', ' between the [GPE] library and the [ORG]'},
#    'Attacker-Arg': {''},
#    'End_Time-Arg': {'About ##-## minutes ago', 'How long ago'}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {''},
#    'Attacker-Arg': {''},
#    'End_Time-Arg': {'About ##-## minutes ago'}},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {'', ' between the [GPE] library and the [ORG]'},
#    'Attacker-Arg': {''},
#    'End_Time-Arg': {'About ##-## minutes ago', 'How long ago'}}},
#  {'event_id': '1013366',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 8,
#   'args_all': {'Target-ARG': set(),
#    'Place-Arg': {'', ' between the [GPE] library and the [ORG]'},
#    'Attacker-Arg': {''},
#    'End_Time-Arg': {'About ##-## minutes ago', 'How long ago'}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {''},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {'About ##-## minutes ago'}},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {'', ' between the [GPE] library and the [ORG]'},
#    'Attacker-Arg': {''},
#    'End_Time-Arg': {'About ##-## minutes ago', 'How long ago'}}},
#  {'event_id': '1015396',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 0,
#   'args_all': {'Target-ARG': set(),
#    'Place-Arg': {' the library'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {' [DATE] semester'}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' the library'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {' [DATE] semester'}},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' the library'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {' [DATE] semester'}}},
#  {'event_id': '1015396',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 1,
#   'args_all': {'Target-ARG': set(),
#    'Place-Arg': {' the library'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {' [DATE] semester'}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' the library'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {' [DATE] semester'}},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' the library'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {' [DATE] semester'}}},
#  {'event_id': '1015396',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 2,
#   'args_all': {'Target-ARG': set(),
#    'Place-Arg': {' the library'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {' [DATE] semester'}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' the library'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {' [DATE] semester'}},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' the library'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {' [DATE] semester'}}},
#  {'event_id': '1015396',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 3,
#   'args_all': {'Target-ARG': set(),
#    'Place-Arg': {' the library'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {' [DATE] semester'}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' the library'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {' [DATE] semester'}},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' the library'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {' [DATE] semester'}}},
#  {'event_id': '1015396',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 4,
#   'args_all': {'Target-ARG': set(),
#    'Place-Arg': {' the library'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {' [DATE] semester'}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' the library'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {' [DATE] semester'}},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' the library'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {' [DATE] semester'}}},
#  {'event_id': '1015396',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 5,
#   'args_all': {'Target-ARG': set(),
#    'Place-Arg': {' the library'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {' [DATE] semester'}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' the library'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {' [DATE] semester'}},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' the library'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {' [DATE] semester'}}},
#  {'event_id': '1015396',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 6,
#   'args_all': {'Target-ARG': set(),
#    'Place-Arg': {' the library'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {' [DATE] semester'}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' the library'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {' [DATE] semester'}},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' the library'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {' [DATE] semester'}}},
#  {'event_id': '1015396',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 7,
#   'args_all': {'Target-ARG': set(),
#    'Place-Arg': {' the library'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {' [DATE] semester'}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' the library'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {' [DATE] semester'}},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' the library'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {' [DATE] semester'}}},
#  {'event_id': '1015396',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 8,
#   'args_all': {'Target-ARG': set(),
#    'Place-Arg': {' the library'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {' [DATE] semester'}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' the library'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {' [DATE] semester'}},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' the library'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {' [DATE] semester'}}},
#  {'event_id': '1015546',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 0,
#   'args_all': {'Target-ARG': {' [PERSON', 'PERSON'},
#    'Place-Arg': set(),
#    'Attacker-Arg': {'PERSON'},
#    'End_Time-Arg': {''}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': set(),
#    'Attacker-Arg': set(),
#    'End_Time-Arg': set()},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': set(),
#    'Attacker-Arg': set(),
#    'End_Time-Arg': set()}},
#  {'event_id': '1015546',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 1,
#   'args_all': {'Target-ARG': {' [PERSON', 'PERSON'},
#    'Place-Arg': set(),
#    'Attacker-Arg': {'PERSON'},
#    'End_Time-Arg': {''}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': set(),
#    'Attacker-Arg': set(),
#    'End_Time-Arg': set()},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': set(),
#    'Attacker-Arg': set(),
#    'End_Time-Arg': set()}},
#  {'event_id': '1015546',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 2,
#   'args_all': {'Target-ARG': {' [PERSON', 'PERSON'},
#    'Place-Arg': set(),
#    'Attacker-Arg': {'PERSON'},
#    'End_Time-Arg': {''}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': set(),
#    'Attacker-Arg': set(),
#    'End_Time-Arg': set()},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': set(),
#    'Attacker-Arg': set(),
#    'End_Time-Arg': set()}},
#  {'event_id': '1015546',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 3,
#   'args_all': {'Target-ARG': {' [PERSON', 'PERSON'},
#    'Place-Arg': set(),
#    'Attacker-Arg': {'PERSON'},
#    'End_Time-Arg': {''}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': set(),
#    'Attacker-Arg': set(),
#    'End_Time-Arg': set()},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': set(),
#    'Attacker-Arg': set(),
#    'End_Time-Arg': set()}},
#  {'event_id': '1015546',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 4,
#   'args_all': {'Target-ARG': {' [PERSON', 'PERSON'},
#    'Place-Arg': set(),
#    'Attacker-Arg': {'PERSON'},
#    'End_Time-Arg': {''}},
#   'args_by_turn': {'Target-ARG': {'PERSON'},
#    'Place-Arg': set(),
#    'Attacker-Arg': {'PERSON'},
#    'End_Time-Arg': set()},
#   'args_accum_by_turn': {'Target-ARG': {'PERSON'},
#    'Place-Arg': set(),
#    'Attacker-Arg': {'PERSON'},
#    'End_Time-Arg': set()}},
#  {'event_id': '1015546',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 5,
#   'args_all': {'Target-ARG': {' [PERSON', 'PERSON'},
#    'Place-Arg': set(),
#    'Attacker-Arg': {'PERSON'},
#    'End_Time-Arg': {''}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': set(),
#    'Attacker-Arg': {'PERSON'},
#    'End_Time-Arg': set()},
#   'args_accum_by_turn': {'Target-ARG': {'PERSON'},
#    'Place-Arg': set(),
#    'Attacker-Arg': {'PERSON'},
#    'End_Time-Arg': set()}},
#  {'event_id': '1015546',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 6,
#   'args_all': {'Target-ARG': {' [PERSON', 'PERSON'},
#    'Place-Arg': set(),
#    'Attacker-Arg': {'PERSON'},
#    'End_Time-Arg': {''}},
#   'args_by_turn': {'Target-ARG': {' [PERSON'},
#    'Place-Arg': set(),
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {''}},
#   'args_accum_by_turn': {'Target-ARG': {' [PERSON', 'PERSON'},
#    'Place-Arg': set(),
#    'Attacker-Arg': {'PERSON'},
#    'End_Time-Arg': {''}}},
#  {'event_id': '1015546',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 7,
#   'args_all': {'Target-ARG': {' [PERSON', 'PERSON'},
#    'Place-Arg': set(),
#    'Attacker-Arg': {'PERSON'},
#    'End_Time-Arg': {''}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': set(),
#    'Attacker-Arg': set(),
#    'End_Time-Arg': set()},
#   'args_accum_by_turn': {'Target-ARG': {' [PERSON', 'PERSON'},
#    'Place-Arg': set(),
#    'Attacker-Arg': {'PERSON'},
#    'End_Time-Arg': {''}}},
#  {'event_id': '1015546',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 8,
#   'args_all': {'Target-ARG': {' [PERSON', 'PERSON'},
#    'Place-Arg': set(),
#    'Attacker-Arg': {'PERSON'},
#    'End_Time-Arg': {''}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': set(),
#    'Attacker-Arg': set(),
#    'End_Time-Arg': set()},
#   'args_accum_by_turn': {'Target-ARG': {' [PERSON', 'PERSON'},
#    'Place-Arg': set(),
#    'Attacker-Arg': {'PERSON'},
#    'End_Time-Arg': {''}}},
#  {'event_id': '1015546',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 9,
#   'args_all': {'Target-ARG': {' [PERSON', 'PERSON'},
#    'Place-Arg': set(),
#    'Attacker-Arg': {'PERSON'},
#    'End_Time-Arg': {''}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': set(),
#    'Attacker-Arg': set(),
#    'End_Time-Arg': set()},
#   'args_accum_by_turn': {'Target-ARG': {' [PERSON', 'PERSON'},
#    'Place-Arg': set(),
#    'Attacker-Arg': {'PERSON'},
#    'End_Time-Arg': {''}}},
#  {'event_id': '1015546',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 10,
#   'args_all': {'Target-ARG': {' [PERSON', 'PERSON'},
#    'Place-Arg': set(),
#    'Attacker-Arg': {'PERSON'},
#    'End_Time-Arg': {''}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': set(),
#    'Attacker-Arg': set(),
#    'End_Time-Arg': set()},
#   'args_accum_by_turn': {'Target-ARG': {' [PERSON', 'PERSON'},
#    'Place-Arg': set(),
#    'Attacker-Arg': {'PERSON'},
#    'End_Time-Arg': {''}}},
#  {'event_id': '1015546',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 11,
#   'args_all': {'Target-ARG': {' [PERSON', 'PERSON'},
#    'Place-Arg': set(),
#    'Attacker-Arg': {'PERSON'},
#    'End_Time-Arg': {''}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': set(),
#    'Attacker-Arg': set(),
#    'End_Time-Arg': set()},
#   'args_accum_by_turn': {'Target-ARG': {' [PERSON', 'PERSON'},
#    'Place-Arg': set(),
#    'Attacker-Arg': {'PERSON'},
#    'End_Time-Arg': {''}}},
#  {'event_id': '1015546',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 12,
#   'args_all': {'Target-ARG': {' [PERSON', 'PERSON'},
#    'Place-Arg': set(),
#    'Attacker-Arg': {'PERSON'},
#    'End_Time-Arg': {''}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': set(),
#    'Attacker-Arg': set(),
#    'End_Time-Arg': set()},
#   'args_accum_by_turn': {'Target-ARG': {' [PERSON', 'PERSON'},
#    'Place-Arg': set(),
#    'Attacker-Arg': {'PERSON'},
#    'End_Time-Arg': {''}}},
#  {'event_id': '1015546',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 13,
#   'args_all': {'Target-ARG': {' [PERSON', 'PERSON'},
#    'Place-Arg': set(),
#    'Attacker-Arg': {'PERSON'},
#    'End_Time-Arg': {''}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': set(),
#    'Attacker-Arg': set(),
#    'End_Time-Arg': set()},
#   'args_accum_by_turn': {'Target-ARG': {' [PERSON', 'PERSON'},
#    'Place-Arg': set(),
#    'Attacker-Arg': {'PERSON'},
#    'End_Time-Arg': {''}}},
#  {'event_id': '1015546',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 14,
#   'args_all': {'Target-ARG': {' [PERSON', 'PERSON'},
#    'Place-Arg': set(),
#    'Attacker-Arg': {'PERSON'},
#    'End_Time-Arg': {''}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': set(),
#    'Attacker-Arg': set(),
#    'End_Time-Arg': set()},
#   'args_accum_by_turn': {'Target-ARG': {' [PERSON', 'PERSON'},
#    'Place-Arg': set(),
#    'Attacker-Arg': {'PERSON'},
#    'End_Time-Arg': {''}}},
#  {'event_id': '1015546',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 15,
#   'args_all': {'Target-ARG': {' [PERSON', 'PERSON'},
#    'Place-Arg': set(),
#    'Attacker-Arg': {'PERSON'},
#    'End_Time-Arg': {''}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': set(),
#    'Attacker-Arg': set(),
#    'End_Time-Arg': set()},
#   'args_accum_by_turn': {'Target-ARG': {' [PERSON', 'PERSON'},
#    'Place-Arg': set(),
#    'Attacker-Arg': {'PERSON'},
#    'End_Time-Arg': {''}}},
#  {'event_id': '1015546',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 16,
#   'args_all': {'Target-ARG': {' [PERSON', 'PERSON'},
#    'Place-Arg': set(),
#    'Attacker-Arg': {'PERSON'},
#    'End_Time-Arg': {''}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': set(),
#    'Attacker-Arg': set(),
#    'End_Time-Arg': set()},
#   'args_accum_by_turn': {'Target-ARG': {' [PERSON', 'PERSON'},
#    'Place-Arg': set(),
#    'Attacker-Arg': {'PERSON'},
#    'End_Time-Arg': {''}}},
#  {'event_id': '1015546',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 17,
#   'args_all': {'Target-ARG': {' [PERSON', 'PERSON'},
#    'Place-Arg': set(),
#    'Attacker-Arg': {'PERSON'},
#    'End_Time-Arg': {''}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': set(),
#    'Attacker-Arg': set(),
#    'End_Time-Arg': set()},
#   'args_accum_by_turn': {'Target-ARG': {' [PERSON', 'PERSON'},
#    'Place-Arg': set(),
#    'Attacker-Arg': {'PERSON'},
#    'End_Time-Arg': {''}}},
#  {'event_id': '1015546',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 18,
#   'args_all': {'Target-ARG': {' [PERSON', 'PERSON'},
#    'Place-Arg': set(),
#    'Attacker-Arg': {'PERSON'},
#    'End_Time-Arg': {''}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': set(),
#    'Attacker-Arg': set(),
#    'End_Time-Arg': set()},
#   'args_accum_by_turn': {'Target-ARG': {' [PERSON', 'PERSON'},
#    'Place-Arg': set(),
#    'Attacker-Arg': {'PERSON'},
#    'End_Time-Arg': {''}}},
#  {'event_id': '1015546',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 19,
#   'args_all': {'Target-ARG': {' [PERSON', 'PERSON'},
#    'Place-Arg': set(),
#    'Attacker-Arg': {'PERSON'},
#    'End_Time-Arg': {''}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': set(),
#    'Attacker-Arg': set(),
#    'End_Time-Arg': set()},
#   'args_accum_by_turn': {'Target-ARG': {' [PERSON', 'PERSON'},
#    'Place-Arg': set(),
#    'Attacker-Arg': {'PERSON'},
#    'End_Time-Arg': {''}}},
#  {'event_id': '1015546',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 20,
#   'args_all': {'Target-ARG': {' [PERSON', 'PERSON'},
#    'Place-Arg': set(),
#    'Attacker-Arg': {'PERSON'},
#    'End_Time-Arg': {''}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': set(),
#    'Attacker-Arg': set(),
#    'End_Time-Arg': set()},
#   'args_accum_by_turn': {'Target-ARG': {' [PERSON', 'PERSON'},
#    'Place-Arg': set(),
#    'Attacker-Arg': {'PERSON'},
#    'End_Time-Arg': {''}}},
#  {'event_id': '1015546',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 21,
#   'args_all': {'Target-ARG': {' [PERSON', 'PERSON'},
#    'Place-Arg': set(),
#    'Attacker-Arg': {'PERSON'},
#    'End_Time-Arg': {''}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': set(),
#    'Attacker-Arg': set(),
#    'End_Time-Arg': set()},
#   'args_accum_by_turn': {'Target-ARG': {' [PERSON', 'PERSON'},
#    'Place-Arg': set(),
#    'Attacker-Arg': {'PERSON'},
#    'End_Time-Arg': {''}}},
#  {'event_id': '1024673',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 0,
#   'args_all': {'Target-ARG': {' ex boyfriend', ' his ex boyfriend'},
#    'Place-Arg': {'', ' east mignon'},
#    'Attacker-Arg': {' his ex boyfriend'},
#    'End_Time-Arg': set()},
#   'args_by_turn': {'Target-ARG': {' ex boyfriend'},
#    'Place-Arg': set(),
#    'Attacker-Arg': {' his ex boyfriend'},
#    'End_Time-Arg': set()},
#   'args_accum_by_turn': {'Target-ARG': {' ex boyfriend'},
#    'Place-Arg': set(),
#    'Attacker-Arg': {' his ex boyfriend'},
#    'End_Time-Arg': set()}},
#  {'event_id': '1024673',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 1,
#   'args_all': {'Target-ARG': {' ex boyfriend', ' his ex boyfriend'},
#    'Place-Arg': {'', ' east mignon'},
#    'Attacker-Arg': {' his ex boyfriend'},
#    'End_Time-Arg': set()},
#   'args_by_turn': {'Target-ARG': {' ex boyfriend'},
#    'Place-Arg': set(),
#    'Attacker-Arg': {' his ex boyfriend'},
#    'End_Time-Arg': set()},
#   'args_accum_by_turn': {'Target-ARG': {' ex boyfriend'},
#    'Place-Arg': set(),
#    'Attacker-Arg': {' his ex boyfriend'},
#    'End_Time-Arg': set()}},
#  {'event_id': '1024673',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 2,
#   'args_all': {'Target-ARG': {' ex boyfriend', ' his ex boyfriend'},
#    'Place-Arg': {'', ' east mignon'},
#    'Attacker-Arg': {' his ex boyfriend'},
#    'End_Time-Arg': set()},
#   'args_by_turn': {'Target-ARG': {' his ex boyfriend'},
#    'Place-Arg': {''},
#    'Attacker-Arg': {' his ex boyfriend'},
#    'End_Time-Arg': set()},
#   'args_accum_by_turn': {'Target-ARG': {' ex boyfriend', ' his ex boyfriend'},
#    'Place-Arg': {''},
#    'Attacker-Arg': {' his ex boyfriend'},
#    'End_Time-Arg': set()}},
#  {'event_id': '1024673',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 3,
#   'args_all': {'Target-ARG': {' ex boyfriend', ' his ex boyfriend'},
#    'Place-Arg': {'', ' east mignon'},
#    'Attacker-Arg': {' his ex boyfriend'},
#    'End_Time-Arg': set()},
#   'args_by_turn': {'Target-ARG': {' his ex boyfriend'},
#    'Place-Arg': {' east mignon'},
#    'Attacker-Arg': {' his ex boyfriend'},
#    'End_Time-Arg': set()},
#   'args_accum_by_turn': {'Target-ARG': {' ex boyfriend', ' his ex boyfriend'},
#    'Place-Arg': {'', ' east mignon'},
#    'Attacker-Arg': {' his ex boyfriend'},
#    'End_Time-Arg': set()}},
#  {'event_id': '1024673',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 4,
#   'args_all': {'Target-ARG': {' ex boyfriend', ' his ex boyfriend'},
#    'Place-Arg': {'', ' east mignon'},
#    'Attacker-Arg': {' his ex boyfriend'},
#    'End_Time-Arg': set()},
#   'args_by_turn': {'Target-ARG': {' his ex boyfriend'},
#    'Place-Arg': {' east mignon'},
#    'Attacker-Arg': {' his ex boyfriend'},
#    'End_Time-Arg': set()},
#   'args_accum_by_turn': {'Target-ARG': {' ex boyfriend', ' his ex boyfriend'},
#    'Place-Arg': {'', ' east mignon'},
#    'Attacker-Arg': {' his ex boyfriend'},
#    'End_Time-Arg': set()}},
#  {'event_id': '1024673',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 5,
#   'args_all': {'Target-ARG': {' ex boyfriend', ' his ex boyfriend'},
#    'Place-Arg': {'', ' east mignon'},
#    'Attacker-Arg': {' his ex boyfriend'},
#    'End_Time-Arg': set()},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': set(),
#    'Attacker-Arg': set(),
#    'End_Time-Arg': set()},
#   'args_accum_by_turn': {'Target-ARG': {' ex boyfriend', ' his ex boyfriend'},
#    'Place-Arg': {'', ' east mignon'},
#    'Attacker-Arg': {' his ex boyfriend'},
#    'End_Time-Arg': set()}},
#  {'event_id': '1024673',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 6,
#   'args_all': {'Target-ARG': {' ex boyfriend', ' his ex boyfriend'},
#    'Place-Arg': {'', ' east mignon'},
#    'Attacker-Arg': {' his ex boyfriend'},
#    'End_Time-Arg': set()},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' east mignon'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': set()},
#   'args_accum_by_turn': {'Target-ARG': {' ex boyfriend', ' his ex boyfriend'},
#    'Place-Arg': {'', ' east mignon'},
#    'Attacker-Arg': {' his ex boyfriend'},
#    'End_Time-Arg': set()}},
#  {'event_id': '1024673',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 7,
#   'args_all': {'Target-ARG': {' ex boyfriend', ' his ex boyfriend'},
#    'Place-Arg': {'', ' east mignon'},
#    'Attacker-Arg': {' his ex boyfriend'},
#    'End_Time-Arg': set()},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' east mignon'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': set()},
#   'args_accum_by_turn': {'Target-ARG': {' ex boyfriend', ' his ex boyfriend'},
#    'Place-Arg': {'', ' east mignon'},
#    'Attacker-Arg': {' his ex boyfriend'},
#    'End_Time-Arg': set()}},
#  {'event_id': '1024673',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 8,
#   'args_all': {'Target-ARG': {' ex boyfriend', ' his ex boyfriend'},
#    'Place-Arg': {'', ' east mignon'},
#    'Attacker-Arg': {' his ex boyfriend'},
#    'End_Time-Arg': set()},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' east mignon'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': set()},
#   'args_accum_by_turn': {'Target-ARG': {' ex boyfriend', ' his ex boyfriend'},
#    'Place-Arg': {'', ' east mignon'},
#    'Attacker-Arg': {' his ex boyfriend'},
#    'End_Time-Arg': set()}},
#  {'event_id': '1025925',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 0,
#   'args_all': {'Target-ARG': set(),
#    'Place-Arg': {' between the library entrance to ## Tremont, and the [ORG] dorm building'},
#    'Attacker-Arg': {' black'},
#    'End_Time-Arg': {'', ' I have walked by twice in the last ## minutes'}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' between the library entrance to ## Tremont, and the [ORG] dorm building'},
#    'Attacker-Arg': {' black'},
#    'End_Time-Arg': {' I have walked by twice in the last ## minutes'}},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' between the library entrance to ## Tremont, and the [ORG] dorm building'},
#    'Attacker-Arg': {' black'},
#    'End_Time-Arg': {' I have walked by twice in the last ## minutes'}}},
#  {'event_id': '1025925',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 1,
#   'args_all': {'Target-ARG': set(),
#    'Place-Arg': {' between the library entrance to ## Tremont, and the [ORG] dorm building'},
#    'Attacker-Arg': {' black'},
#    'End_Time-Arg': {'', ' I have walked by twice in the last ## minutes'}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' between the library entrance to ## Tremont, and the [ORG] dorm building'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {' I have walked by twice in the last ## minutes'}},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' between the library entrance to ## Tremont, and the [ORG] dorm building'},
#    'Attacker-Arg': {' black'},
#    'End_Time-Arg': {' I have walked by twice in the last ## minutes'}}},
#  {'event_id': '1025925',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 2,
#   'args_all': {'Target-ARG': set(),
#    'Place-Arg': {' between the library entrance to ## Tremont, and the [ORG] dorm building'},
#    'Attacker-Arg': {' black'},
#    'End_Time-Arg': {'', ' I have walked by twice in the last ## minutes'}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' between the library entrance to ## Tremont, and the [ORG] dorm building'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {' I have walked by twice in the last ## minutes'}},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' between the library entrance to ## Tremont, and the [ORG] dorm building'},
#    'Attacker-Arg': {' black'},
#    'End_Time-Arg': {' I have walked by twice in the last ## minutes'}}},
#  {'event_id': '1025925',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 3,
#   'args_all': {'Target-ARG': set(),
#    'Place-Arg': {' between the library entrance to ## Tremont, and the [ORG] dorm building'},
#    'Attacker-Arg': {' black'},
#    'End_Time-Arg': {'', ' I have walked by twice in the last ## minutes'}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' between the library entrance to ## Tremont, and the [ORG] dorm building'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {''}},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' between the library entrance to ## Tremont, and the [ORG] dorm building'},
#    'Attacker-Arg': {' black'},
#    'End_Time-Arg': {'', ' I have walked by twice in the last ## minutes'}}},
#  {'event_id': '1025925',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 4,
#   'args_all': {'Target-ARG': set(),
#    'Place-Arg': {' between the library entrance to ## Tremont, and the [ORG] dorm building'},
#    'Attacker-Arg': {' black'},
#    'End_Time-Arg': {'', ' I have walked by twice in the last ## minutes'}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' between the library entrance to ## Tremont, and the [ORG] dorm building'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': set()},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' between the library entrance to ## Tremont, and the [ORG] dorm building'},
#    'Attacker-Arg': {' black'},
#    'End_Time-Arg': {'', ' I have walked by twice in the last ## minutes'}}},
#  {'event_id': '1025925',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 5,
#   'args_all': {'Target-ARG': set(),
#    'Place-Arg': {' between the library entrance to ## Tremont, and the [ORG] dorm building'},
#    'Attacker-Arg': {' black'},
#    'End_Time-Arg': {'', ' I have walked by twice in the last ## minutes'}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' between the library entrance to ## Tremont, and the [ORG] dorm building'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': set()},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' between the library entrance to ## Tremont, and the [ORG] dorm building'},
#    'Attacker-Arg': {' black'},
#    'End_Time-Arg': {'', ' I have walked by twice in the last ## minutes'}}},
#  {'event_id': '1025925',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 6,
#   'args_all': {'Target-ARG': set(),
#    'Place-Arg': {' between the library entrance to ## Tremont, and the [ORG] dorm building'},
#    'Attacker-Arg': {' black'},
# ...
#    'End_Time-Arg': {' between #:##-##:##pm'}},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' bomb shelter'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {' between #:##-##:##pm'}}},
#  {'event_id': '1403331',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 8,
#   'args_all': {'Target-ARG': set(),
#    'Place-Arg': {' bomb shelter'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {' between #:##-##:##pm'}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': set(),
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {' between #:##-##:##pm'}},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' bomb shelter'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {' between #:##-##:##pm'}}},
#  {'event_id': '1403331',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 9,
#   'args_all': {'Target-ARG': set(),
#    'Place-Arg': {' bomb shelter'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {' between #:##-##:##pm'}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': set(),
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {' between #:##-##:##pm'}},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' bomb shelter'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {' between #:##-##:##pm'}}},
#  {'event_id': '1403331',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 10,
#   'args_all': {'Target-ARG': set(),
#    'Place-Arg': {' bomb shelter'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {' between #:##-##:##pm'}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': set(),
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {' between #:##-##:##pm'}},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' bomb shelter'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {' between #:##-##:##pm'}}},
#  {'event_id': '1403331',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 11,
#   'args_all': {'Target-ARG': set(),
#    'Place-Arg': {' bomb shelter'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {' between #:##-##:##pm'}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': set(),
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {' between #:##-##:##pm'}},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' bomb shelter'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {' between #:##-##:##pm'}}},
#  {'event_id': '1403331',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 12,
#   'args_all': {'Target-ARG': set(),
#    'Place-Arg': {' bomb shelter'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {' between #:##-##:##pm'}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': set(),
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {' between #:##-##:##pm'}},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' bomb shelter'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {' between #:##-##:##pm'}}},
#  {'event_id': '1403331',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 13,
#   'args_all': {'Target-ARG': set(),
#    'Place-Arg': {' bomb shelter'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {' between #:##-##:##pm'}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': set(),
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {' between #:##-##:##pm'}},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' bomb shelter'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {' between #:##-##:##pm'}}},
#  {'event_id': '1403331',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 14,
#   'args_all': {'Target-ARG': set(),
#    'Place-Arg': {' bomb shelter'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {' between #:##-##:##pm'}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': set(),
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {' between #:##-##:##pm'}},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' bomb shelter'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {' between #:##-##:##pm'}}},
#  {'event_id': '1403331',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 15,
#   'args_all': {'Target-ARG': set(),
#    'Place-Arg': {' bomb shelter'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {' between #:##-##:##pm'}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': set(),
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {' between #:##-##:##pm'}},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' bomb shelter'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {' between #:##-##:##pm'}}},
#  {'event_id': '1403331',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 16,
#   'args_all': {'Target-ARG': set(),
#    'Place-Arg': {' bomb shelter'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {' between #:##-##:##pm'}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': set(),
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {' between #:##-##:##pm'}},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': {' bomb shelter'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {' between #:##-##:##pm'}}},
#  {'event_id': '1403557',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 0,
#   'args_all': {'Target-ARG': {'', ' my ex'},
#    'Place-Arg': {'', ' Greensboro'},
#    'Attacker-Arg': {'', ' my ex'},
#    'End_Time-Arg': {' my ex threatened to shoot me in the head over the phone this evening',
#     ' this evening'}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': set(),
#    'Attacker-Arg': set(),
#    'End_Time-Arg': set()},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': set(),
#    'Attacker-Arg': set(),
#    'End_Time-Arg': set()}},
#  {'event_id': '1403557',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 1,
#   'args_all': {'Target-ARG': {'', ' my ex'},
#    'Place-Arg': {'', ' Greensboro'},
#    'Attacker-Arg': {'', ' my ex'},
#    'End_Time-Arg': {' my ex threatened to shoot me in the head over the phone this evening',
#     ' this evening'}},
#   'args_by_turn': {'Target-ARG': set(),
#    'Place-Arg': set(),
#    'Attacker-Arg': set(),
#    'End_Time-Arg': set()},
#   'args_accum_by_turn': {'Target-ARG': set(),
#    'Place-Arg': set(),
#    'Attacker-Arg': set(),
#    'End_Time-Arg': set()}},
#  {'event_id': '1403557',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 2,
#   'args_all': {'Target-ARG': {'', ' my ex'},
#    'Place-Arg': {'', ' Greensboro'},
#    'Attacker-Arg': {'', ' my ex'},
#    'End_Time-Arg': {' my ex threatened to shoot me in the head over the phone this evening',
#     ' this evening'}},
#   'args_by_turn': {'Target-ARG': {' my ex'},
#    'Place-Arg': set(),
#    'Attacker-Arg': {' my ex'},
#    'End_Time-Arg': {' my ex threatened to shoot me in the head over the phone this evening'}},
#   'args_accum_by_turn': {'Target-ARG': {' my ex'},
#    'Place-Arg': set(),
#    'Attacker-Arg': {' my ex'},
#    'End_Time-Arg': {' my ex threatened to shoot me in the head over the phone this evening'}}},
#  {'event_id': '1403557',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 3,
#   'args_all': {'Target-ARG': {'', ' my ex'},
#    'Place-Arg': {'', ' Greensboro'},
#    'Attacker-Arg': {'', ' my ex'},
#    'End_Time-Arg': {' my ex threatened to shoot me in the head over the phone this evening',
#     ' this evening'}},
#   'args_by_turn': {'Target-ARG': {' my ex'},
#    'Place-Arg': {''},
#    'Attacker-Arg': {' my ex'},
#    'End_Time-Arg': {' this evening'}},
#   'args_accum_by_turn': {'Target-ARG': {' my ex'},
#    'Place-Arg': {''},
#    'Attacker-Arg': {' my ex'},
#    'End_Time-Arg': {' my ex threatened to shoot me in the head over the phone this evening',
#     ' this evening'}}},
#  {'event_id': '1403557',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 4,
#   'args_all': {'Target-ARG': {'', ' my ex'},
#    'Place-Arg': {'', ' Greensboro'},
#    'Attacker-Arg': {'', ' my ex'},
#    'End_Time-Arg': {' my ex threatened to shoot me in the head over the phone this evening',
#     ' this evening'}},
#   'args_by_turn': {'Target-ARG': {' my ex'},
#    'Place-Arg': {''},
#    'Attacker-Arg': {' my ex'},
#    'End_Time-Arg': {' this evening'}},
#   'args_accum_by_turn': {'Target-ARG': {' my ex'},
#    'Place-Arg': {''},
#    'Attacker-Arg': {' my ex'},
#    'End_Time-Arg': {' my ex threatened to shoot me in the head over the phone this evening',
#     ' this evening'}}},
#  {'event_id': '1403557',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 5,
#   'args_all': {'Target-ARG': {'', ' my ex'},
#    'Place-Arg': {'', ' Greensboro'},
#    'Attacker-Arg': {'', ' my ex'},
#    'End_Time-Arg': {' my ex threatened to shoot me in the head over the phone this evening',
#     ' this evening'}},
#   'args_by_turn': {'Target-ARG': {' my ex'},
#    'Place-Arg': {''},
#    'Attacker-Arg': {' my ex'},
#    'End_Time-Arg': {' this evening'}},
#   'args_accum_by_turn': {'Target-ARG': {' my ex'},
#    'Place-Arg': {''},
#    'Attacker-Arg': {' my ex'},
#    'End_Time-Arg': {' my ex threatened to shoot me in the head over the phone this evening',
#     ' this evening'}}},
#  {'event_id': '1403557',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 6,
#   'args_all': {'Target-ARG': {'', ' my ex'},
#    'Place-Arg': {'', ' Greensboro'},
#    'Attacker-Arg': {'', ' my ex'},
#    'End_Time-Arg': {' my ex threatened to shoot me in the head over the phone this evening',
#     ' this evening'}},
#   'args_by_turn': {'Target-ARG': {' my ex'},
#    'Place-Arg': {''},
#    'Attacker-Arg': {' my ex'},
#    'End_Time-Arg': {' this evening'}},
#   'args_accum_by_turn': {'Target-ARG': {' my ex'},
#    'Place-Arg': {''},
#    'Attacker-Arg': {' my ex'},
#    'End_Time-Arg': {' my ex threatened to shoot me in the head over the phone this evening',
#     ' this evening'}}},
#  {'event_id': '1403557',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 7,
#   'args_all': {'Target-ARG': {'', ' my ex'},
#    'Place-Arg': {'', ' Greensboro'},
#    'Attacker-Arg': {'', ' my ex'},
#    'End_Time-Arg': {' my ex threatened to shoot me in the head over the phone this evening',
#     ' this evening'}},
#   'args_by_turn': {'Target-ARG': {' my ex'},
#    'Place-Arg': {' Greensboro'},
#    'Attacker-Arg': {' my ex'},
#    'End_Time-Arg': {' this evening'}},
#   'args_accum_by_turn': {'Target-ARG': {' my ex'},
#    'Place-Arg': {'', ' Greensboro'},
#    'Attacker-Arg': {' my ex'},
#    'End_Time-Arg': {' my ex threatened to shoot me in the head over the phone this evening',
#     ' this evening'}}},
#  {'event_id': '1403557',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 8,
#   'args_all': {'Target-ARG': {'', ' my ex'},
#    'Place-Arg': {'', ' Greensboro'},
#    'Attacker-Arg': {'', ' my ex'},
#    'End_Time-Arg': {' my ex threatened to shoot me in the head over the phone this evening',
#     ' this evening'}},
#   'args_by_turn': {'Target-ARG': {' my ex'},
#    'Place-Arg': {''},
#    'Attacker-Arg': {' my ex'},
#    'End_Time-Arg': {' this evening'}},
#   'args_accum_by_turn': {'Target-ARG': {' my ex'},
#    'Place-Arg': {'', ' Greensboro'},
#    'Attacker-Arg': {' my ex'},
#    'End_Time-Arg': {' my ex threatened to shoot me in the head over the phone this evening',
#     ' this evening'}}},
#  {'event_id': '1403557',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 9,
#   'args_all': {'Target-ARG': {'', ' my ex'},
#    'Place-Arg': {'', ' Greensboro'},
#    'Attacker-Arg': {'', ' my ex'},
#    'End_Time-Arg': {' my ex threatened to shoot me in the head over the phone this evening',
#     ' this evening'}},
#   'args_by_turn': {'Target-ARG': {''},
#    'Place-Arg': {''},
#    'Attacker-Arg': {''},
#    'End_Time-Arg': {' this evening'}},
#   'args_accum_by_turn': {'Target-ARG': {'', ' my ex'},
#    'Place-Arg': {'', ' Greensboro'},
#    'Attacker-Arg': {'', ' my ex'},
#    'End_Time-Arg': {' my ex threatened to shoot me in the head over the phone this evening',
#     ' this evening'}}},
#  {'event_id': '1403557',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 10,
#   'args_all': {'Target-ARG': {'', ' my ex'},
#    'Place-Arg': {'', ' Greensboro'},
#    'Attacker-Arg': {'', ' my ex'},
#    'End_Time-Arg': {' my ex threatened to shoot me in the head over the phone this evening',
#     ' this evening'}},
#   'args_by_turn': {'Target-ARG': {''},
#    'Place-Arg': {''},
#    'Attacker-Arg': {' my ex'},
#    'End_Time-Arg': {' this evening'}},
#   'args_accum_by_turn': {'Target-ARG': {'', ' my ex'},
#    'Place-Arg': {'', ' Greensboro'},
#    'Attacker-Arg': {'', ' my ex'},
#    'End_Time-Arg': {' my ex threatened to shoot me in the head over the phone this evening',
#     ' this evening'}}},
#  {'event_id': '1403557',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 11,
#   'args_all': {'Target-ARG': {'', ' my ex'},
#    'Place-Arg': {'', ' Greensboro'},
#    'Attacker-Arg': {'', ' my ex'},
#    'End_Time-Arg': {' my ex threatened to shoot me in the head over the phone this evening',
#     ' this evening'}},
#   'args_by_turn': {'Target-ARG': {''},
#    'Place-Arg': {''},
#    'Attacker-Arg': {' my ex'},
#    'End_Time-Arg': {' this evening'}},
#   'args_accum_by_turn': {'Target-ARG': {'', ' my ex'},
#    'Place-Arg': {'', ' Greensboro'},
#    'Attacker-Arg': {'', ' my ex'},
#    'End_Time-Arg': {' my ex threatened to shoot me in the head over the phone this evening',
#     ' this evening'}}},
#  {'event_id': '1405271',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 0,
#   'args_all': {'Target-ARG': {' young [NORP] male'},
#    'Place-Arg': {'',
#     ' on the corner of [ORG]',
#     ' the corner of [ORG]',
#     ' the corner of [ORG] and [PERSON]'},
#    'Attacker-Arg': {' young [NORP] male'},
#    'End_Time-Arg': {' # minutes ago'}},
#   'args_by_turn': {'Target-ARG': {' young [NORP] male'},
#    'Place-Arg': {' on the corner of [ORG]'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': set()},
#   'args_accum_by_turn': {'Target-ARG': {' young [NORP] male'},
#    'Place-Arg': {' on the corner of [ORG]'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': set()}},
#  {'event_id': '1405271',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 1,
#   'args_all': {'Target-ARG': {' young [NORP] male'},
#    'Place-Arg': {'',
#     ' on the corner of [ORG]',
#     ' the corner of [ORG]',
#     ' the corner of [ORG] and [PERSON]'},
#    'Attacker-Arg': {' young [NORP] male'},
#    'End_Time-Arg': {' # minutes ago'}},
#   'args_by_turn': {'Target-ARG': {' young [NORP] male'},
#    'Place-Arg': {' on the corner of [ORG]'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': set()},
#   'args_accum_by_turn': {'Target-ARG': {' young [NORP] male'},
#    'Place-Arg': {' on the corner of [ORG]'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': set()}},
#  {'event_id': '1405271',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 2,
#   'args_all': {'Target-ARG': {' young [NORP] male'},
#    'Place-Arg': {'',
#     ' on the corner of [ORG]',
#     ' the corner of [ORG]',
#     ' the corner of [ORG] and [PERSON]'},
#    'Attacker-Arg': {' young [NORP] male'},
#    'End_Time-Arg': {' # minutes ago'}},
#   'args_by_turn': {'Target-ARG': {' young [NORP] male'},
#    'Place-Arg': {' the corner of [ORG]'},
#    'Attacker-Arg': {' young [NORP] male'},
#    'End_Time-Arg': set()},
#   'args_accum_by_turn': {'Target-ARG': {' young [NORP] male'},
#    'Place-Arg': {' on the corner of [ORG]', ' the corner of [ORG]'},
#    'Attacker-Arg': {' young [NORP] male'},
#    'End_Time-Arg': set()}},
#  {'event_id': '1405271',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 3,
#   'args_all': {'Target-ARG': {' young [NORP] male'},
#    'Place-Arg': {'',
#     ' on the corner of [ORG]',
#     ' the corner of [ORG]',
#     ' the corner of [ORG] and [PERSON]'},
#    'Attacker-Arg': {' young [NORP] male'},
#    'End_Time-Arg': {' # minutes ago'}},
#   'args_by_turn': {'Target-ARG': {' young [NORP] male'},
#    'Place-Arg': {' the corner of [ORG]'},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': set()},
#   'args_accum_by_turn': {'Target-ARG': {' young [NORP] male'},
#    'Place-Arg': {' on the corner of [ORG]', ' the corner of [ORG]'},
#    'Attacker-Arg': {' young [NORP] male'},
#    'End_Time-Arg': set()}},
#  {'event_id': '1405271',
#   'domain': 'HarassmentAbuse',
#   'turn_id': 4,
#   'args_all': {'Target-ARG': {' young [NORP] male'},
#    'Place-Arg': {'',
#     ' on the corner of [ORG]',
#     ' the corner of [ORG]',
#     ' the corner of [ORG] and [PERSON]'},
#    'Attacker-Arg': {' young [NORP] male'},
#    'End_Time-Arg': {' # minutes ago'}},
#   'args_by_turn': {'Target-ARG': {' young [NORP] male'},
#    'Place-Arg': {''},
#    'Attacker-Arg': set(),
#    'End_Time-Arg': {' # minutes ago'}},
#   'args_accum_by_turn': {'Target-ARG': {' young [NORP] male'},
#    'Place-Arg': {'', ' on the corner of [ORG]', ' the corner of [ORG]'},
#    'Attacker-Arg': {' young [NORP] male'},
#    'End_Time-Arg': {' # minutes ago'}}},
#  ...]

# %%
df_convos = pd.DataFrame(convos)
df_convos
# Out:
#      event_id           domain  turn_id  \
# 0     1001270  HarassmentAbuse        0
# 1     1001270  HarassmentAbuse        1
# 2     1001270  HarassmentAbuse        2
# 3     1001270  HarassmentAbuse        3
# 4     1001270  HarassmentAbuse        4
# ...       ...              ...      ...
# 5333   993897    TheftLostItem        4
# 5334   993897    TheftLostItem        5
# 5335   993897    TheftLostItem        6
# 5336   993897    TheftLostItem        7
# 5337   993897    TheftLostItem        8
#
#                                                args_all  \
# 0     {'Target-ARG': {}, 'Place-Arg': {'ORG] Locker ...
# 1     {'Target-ARG': {}, 'Place-Arg': {'ORG] Locker ...
# 2     {'Target-ARG': {}, 'Place-Arg': {'ORG] Locker ...
# 3     {'Target-ARG': {}, 'Place-Arg': {'ORG] Locker ...
# 4     {'Target-ARG': {}, 'Place-Arg': {'ORG] Locker ...
# ...                                                 ...
# 5333  {'Target-ARG': {}, 'Place-Arg': {' my garage'}...
# 5334  {'Target-ARG': {}, 'Place-Arg': {' my garage'}...
# 5335  {'Target-ARG': {}, 'Place-Arg': {' my garage'}...
# 5336  {'Target-ARG': {}, 'Place-Arg': {' my garage'}...
# 5337  {'Target-ARG': {}, 'Place-Arg': {' my garage'}...
#
#                                            args_by_turn  \
# 0     {'Target-ARG': {}, 'Place-Arg': {'ORG] Locker ...
# 1     {'Target-ARG': {}, 'Place-Arg': {'ORG] Locker ...
# 2     {'Target-ARG': {}, 'Place-Arg': {'ORG] Locker ...
# 3     {'Target-ARG': {}, 'Place-Arg': {'ORG] Locker ...
# 4     {'Target-ARG': {}, 'Place-Arg': {'ORG] Locker ...
# ...                                                 ...
# 5333  {'Target-ARG': {}, 'Place-Arg': {}, 'Attacker-...
# 5334  {'Target-ARG': {}, 'Place-Arg': {}, 'Attacker-...
# 5335  {'Target-ARG': {}, 'Place-Arg': {}, 'Attacker-...
# 5336  {'Target-ARG': {}, 'Place-Arg': {}, 'Attacker-...
# 5337  {'Target-ARG': {}, 'Place-Arg': {}, 'Attacker-...
#
#                                      args_accum_by_turn
# 0     {'Target-ARG': {}, 'Place-Arg': {'ORG] Locker ...
# 1     {'Target-ARG': {}, 'Place-Arg': {'ORG] Locker ...
# 2     {'Target-ARG': {}, 'Place-Arg': {'ORG] Locker ...
# 3     {'Target-ARG': {}, 'Place-Arg': {'ORG] Locker ...
# 4     {'Target-ARG': {}, 'Place-Arg': {'ORG] Locker ...
# ...                                                 ...
# 5333  {'Target-ARG': {}, 'Place-Arg': {' my garage'}...
# 5334  {'Target-ARG': {}, 'Place-Arg': {' my garage'}...
# 5335  {'Target-ARG': {}, 'Place-Arg': {' my garage'}...
# 5336  {'Target-ARG': {}, 'Place-Arg': {' my garage'}...
# 5337  {'Target-ARG': {}, 'Place-Arg': {' my garage'}...
#
# [5338 rows x 6 columns]

# %%
# Calculate the percentage of event information (argument) provided by user in the first message
# , out of the whole conversation
# By incident categories
def count_hit(row):
#     print(row)
    eventArgs = row['args_accum_by_turn']
    eventCat = row['domain']

    args = []
    for arg in eventArgs:
        if len(eventArgs[arg]) > 0:
            args.append(arg)
    if eventCat == 'HarassmentAbuse':
        s = ['Place-Arg', 'Target-ARG', 'Attacker-Arg', 'End_Time-Arg']
        return len([i for i in args if i in s]) / len(s)
    elif eventCat == 'TheftLostItem':
        s = ['Place-Arg', 'Target-ARG', 'Attacker-Arg', 'End_Time-Arg', 
        'Target_Object-Arg', 'Start_Time-Arg']
        return len([i for i in args if i in s]) / len(s)

df_convos['ratio_args'] = df_convos.apply(count_hit, axis=1)
df_convos

df_convos.groupby(['domain', 'turn_id'])['ratio_args'].mean()
# df_convos.groupby(['domain', 'turn_id'])['ratio_args'].std()
# Out:
# domain           turn_id
# HarassmentAbuse  0          0.353679
#                  1          0.387960
#                  2          0.434783
#                  3          0.467391
#                  4          0.496656
#                               ...
# TheftLostItem    23         0.333333
#                  24         0.375000
#                  25         0.333333
#                  26         0.666667
#                  27         0.666667
# Name: ratio_args, Length: 68, dtype: float64

# %%
(
    df_convos.groupby(['domain'])['ratio_args'].count(),
    df_convos.groupby(['domain'])['ratio_args'].mean(),
    df_convos.groupby(['domain'])['ratio_args'].std()
)
# Out:
# (domain
#  HarassmentAbuse    2802
#  TheftLostItem      2536
#  Name: ratio_args, dtype: int64,
#  domain
#  HarassmentAbuse    0.488669
#  TheftLostItem      0.303299
#  Name: ratio_args, dtype: float64,
#  domain
#  HarassmentAbuse    0.309078
#  TheftLostItem      0.291125
#  Name: ratio_args, dtype: float64)

# %%
ratio_Harass = df_convos.groupby(['domain', 'turn_id'])['ratio_args'].mean()['HarassmentAbuse']
ratio_Theft = df_convos.groupby(['domain', 'turn_id'])['ratio_args'].mean()['TheftLostItem']

plt.plot(ratio_Harass, label='HarassmentAbuse')
plt.plot(ratio_Theft, label='TheftLostItem')

plt.xlabel('conversation turn#')
plt.ylabel('% of event arguments collected')

plt.legend()
